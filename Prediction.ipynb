# %% [markdown]
# Import Dataset

# %%
# !pip install kagglehub --upgrade
# Out:
# ...
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: C:\Users\lukad\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
import pandas as pd

# Load the CSV file into a DataFrame
csv_file_path = "E:\Personal Project\lung_cancer_data.csv"
df = pd.read_csv(csv_file_path)

# Display the first few rows of the DataFrame
df.head()
# Out:
#     Patient_ID  Age  Gender Smoking_History  Tumor_Size_mm Tumor_Location  \
# 0  Patient0000   68    Male  Current Smoker      81.678677     Lower Lobe
# 1  Patient0001   58    Male    Never Smoked      78.448272     Lower Lobe
# 2  Patient0002   44    Male   Former Smoker      67.714305     Lower Lobe
# 3  Patient0003   72    Male  Current Smoker      70.806008     Lower Lobe
# 4  Patient0004   37  Female    Never Smoked      87.272433     Lower Lobe
#
#        Stage          Treatment  Survival_Months         Ethnicity  ...  \
# 0  Stage III            Surgery               44          Hispanic  ...
# 1    Stage I  Radiation Therapy              101         Caucasian  ...
# 2    Stage I       Chemotherapy               69  African American  ...
# 3  Stage III       Chemotherapy               95  African American  ...
# 4   Stage IV  Radiation Therapy              105             Asian  ...
#
#   Alanine_Aminotransferase_Level Aspartate_Aminotransferase_Level  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23658 entries, 0 to 23657
# Data columns (total 38 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Patient_ID                        23658 non-null  object
#  1   Age                               23658 non-null  int64
#  2   Gender                            23658 non-null  object
#  3   Smoking_History                   23658 non-null  object
#  4   Tumor_Size_mm                     23658 non-null  float64
#  5   Tumor_Location                    23658 non-null  object
#  6   Stage                             23658 non-null  object
#  7   Treatment                         23658 non-null  object
#  8   Survival_Months                   23658 non-null  int64
#  9   Ethnicity                         23658 non-null  object
#  10  Insurance_Type                    23658 non-null  object
# ...

# %%
df.isna().sum()
# Out:
# Patient_ID                          0
# Age                                 0
# Gender                              0
# Smoking_History                     0
# Tumor_Size_mm                       0
# Tumor_Location                      0
# Stage                               0
# Treatment                           0
# Survival_Months                     0
# Ethnicity                           0
# Insurance_Type                      0
# Family_History                      0
# Comorbidity_Diabetes                0
# Comorbidity_Hypertension            0
# Comorbidity_Heart_Disease           0
# Comorbidity_Chronic_Lung_Disease    0
# Comorbidity_Kidney_Disease          0
# Comorbidity_Autoimmune_Disease      0
# Comorbidity_Other                   0
# Performance_Status                  0
# Blood_Pressure_Systolic             0
# Blood_Pressure_Diastolic            0
# Blood_Pressure_Pulse                0
# Hemoglobin_Level                    0
# White_Blood_Cell_Count              0
# ...

# %%
print("Jumlah Duplikasi Data: ", df.duplicated().sum())
# Out:
# Jumlah Duplikasi Data:  0

# %%
import seaborn as sns

sns.heatmap(df.isna())
# Out:
# <Axes: >

# %% [markdown]
# Kita bisa lihat bahwa tidak ada data yang missing

# %%
df.describe()
# Out:
#                 Age  Tumor_Size_mm  Survival_Months  Performance_Status  \
# count  23658.000000   23658.000000     23658.000000        23658.000000
# mean      54.439344      55.383736        59.863809            1.999915
# std       14.396386      26.004354        34.246042            1.413675
# min       30.000000      10.004279         1.000000            0.000000
# 25%       42.000000      32.972797        30.000000            1.000000
# 50%       54.000000      55.296297        60.000000            2.000000
# 75%       67.000000      78.190014        89.000000            3.000000
# max       79.000000      99.990554       119.000000            4.000000
#
#        Blood_Pressure_Systolic  Blood_Pressure_Diastolic  \
# count             23658.000000              23658.000000
# mean                134.462381                 84.475780
# std                  26.020492                 14.409826
# min                  90.000000                 60.000000
# ...

# %%
df.drop(['Patient_ID'], axis=1, inplace=True)

# %%
df.head()
# Out:
#    Age  Gender Smoking_History  Tumor_Size_mm Tumor_Location      Stage  \
# 0   68    Male  Current Smoker      81.678677     Lower Lobe  Stage III
# 1   58    Male    Never Smoked      78.448272     Lower Lobe    Stage I
# 2   44    Male   Former Smoker      67.714305     Lower Lobe    Stage I
# 3   72    Male  Current Smoker      70.806008     Lower Lobe  Stage III
# 4   37  Female    Never Smoked      87.272433     Lower Lobe   Stage IV
#
#            Treatment  Survival_Months         Ethnicity Insurance_Type  ...  \
# 0            Surgery               44          Hispanic       Medicare  ...
# 1  Radiation Therapy              101         Caucasian        Private  ...
# 2       Chemotherapy               69  African American          Other  ...
# 3       Chemotherapy               95  African American       Medicare  ...
# 4  Radiation Therapy              105             Asian       Medicaid  ...
#
#   Alanine_Aminotransferase_Level Aspartate_Aminotransferase_Level  \
# ...

# %%
df['Smoking_History']
# Out:
# 0        Current Smoker
# 1          Never Smoked
# 2         Former Smoker
# 3        Current Smoker
# 4          Never Smoked
#               ...
# 23653     Former Smoker
# 23654    Current Smoker
# 23655     Former Smoker
# 23656     Former Smoker
# 23657     Former Smoker
# Name: Smoking_History, Length: 23658, dtype: object

# %%
import matplotlib.pyplot as plt

# Convert categorical data to numeric
df_numeric = df.select_dtypes(include=[float, int])

plt.figure(figsize=(40, 20))
sns.heatmap(df_numeric.corr())
top_corr_features = df_numeric.corr().index
g = sns.heatmap(df_numeric[top_corr_features].corr(), annot=True, linewidth=.10, cmap="rocket")

# %%
df.nunique()
# Out:
# Age                                    50
# Gender                                  2
# Smoking_History                         3
# Tumor_Size_mm                       23658
# Tumor_Location                          3
# Stage                                   4
# Treatment                               4
# Survival_Months                       119
# Ethnicity                               5
# Insurance_Type                          4
# Family_History                          2
# Comorbidity_Diabetes                    2
# Comorbidity_Hypertension                2
# Comorbidity_Heart_Disease               2
# Comorbidity_Chronic_Lung_Disease        2
# Comorbidity_Kidney_Disease              2
# Comorbidity_Autoimmune_Disease          2
# Comorbidity_Other                       2
# Performance_Status                      5
# Blood_Pressure_Systolic                90
# Blood_Pressure_Diastolic               50
# Blood_Pressure_Pulse                   40
# ...

# %%
df
# Out:
#        Age  Gender Smoking_History  Tumor_Size_mm Tumor_Location      Stage  \
# 0       68    Male  Current Smoker      81.678677     Lower Lobe  Stage III
# 1       58    Male    Never Smoked      78.448272     Lower Lobe    Stage I
# 2       44    Male   Former Smoker      67.714305     Lower Lobe    Stage I
# 3       72    Male  Current Smoker      70.806008     Lower Lobe  Stage III
# 4       37  Female    Never Smoked      87.272433     Lower Lobe   Stage IV
# ...    ...     ...             ...            ...            ...        ...
# 23653   45    Male   Former Smoker      91.279410    Middle Lobe    Stage I
# 23654   31    Male  Current Smoker      45.139048     Upper Lobe   Stage IV
# 23655   74    Male   Former Smoker      89.640323     Upper Lobe   Stage IV
# 23656   47  Female   Former Smoker      45.770358    Middle Lobe    Stage I
# 23657   64    Male   Former Smoker      13.460912     Upper Lobe    Stage I
#
# ...

# %%
col = list(df.columns)
print(col)
# Out:
# ['Age', 'Gender', 'Smoking_History', 'Tumor_Size_mm', 'Tumor_Location', 'Stage', 'Treatment', 'Survival_Months', 'Ethnicity', 'Insurance_Type', 'Family_History', 'Comorbidity_Diabetes', 'Comorbidity_Hypertension', 'Comorbidity_Heart_Disease', 'Comorbidity_Chronic_Lung_Disease', 'Comorbidity_Kidney_Disease', 'Comorbidity_Autoimmune_Disease', 'Comorbidity_Other', 'Performance_Status', 'Blood_Pressure_Systolic', 'Blood_Pressure_Diastolic', 'Blood_Pressure_Pulse', 'Hemoglobin_Level', 'White_Blood_Cell_Count', 'Platelet_Count', 'Albumin_Level', 'Alkaline_Phosphatase_Level', 'Alanine_Aminotransferase_Level', 'Aspartate_Aminotransferase_Level', 'Creatinine_Level', 'LDH_Level', 'Calcium_Level', 'Phosphorus_Level', 'Glucose_Level', 'Potassium_Level', 'Sodium_Level', 'Smoking_Pack_Years']

# %% [markdown]
# Delete 'Patient_ID' to prevent overfitting

# %%
df
# Out:
#        Age  Gender Smoking_History  Tumor_Size_mm Tumor_Location      Stage  \
# 0       68    Male  Current Smoker      81.678677     Lower Lobe  Stage III
# 1       58    Male    Never Smoked      78.448272     Lower Lobe    Stage I
# 2       44    Male   Former Smoker      67.714305     Lower Lobe    Stage I
# 3       72    Male  Current Smoker      70.806008     Lower Lobe  Stage III
# 4       37  Female    Never Smoked      87.272433     Lower Lobe   Stage IV
# ...    ...     ...             ...            ...            ...        ...
# 23653   45    Male   Former Smoker      91.279410    Middle Lobe    Stage I
# 23654   31    Male  Current Smoker      45.139048     Upper Lobe   Stage IV
# 23655   74    Male   Former Smoker      89.640323     Upper Lobe   Stage IV
# 23656   47  Female   Former Smoker      45.770358    Middle Lobe    Stage I
# 23657   64    Male   Former Smoker      13.460912     Upper Lobe    Stage I
#
# ...

# %%
df['Stage']
# Out:
# 0        Stage III
# 1          Stage I
# 2          Stage I
# 3        Stage III
# 4         Stage IV
#            ...
# 23653      Stage I
# 23654     Stage IV
# 23655     Stage IV
# 23656      Stage I
# 23657      Stage I
# Name: Stage, Length: 23658, dtype: object

# %%
plt.figure(figsize=(10, 5))
sns.histplot(data=df, x='Stage', kde=True, palette='hot')
# Out:
# C:\Users\lukad\AppData\Local\Temp\ipykernel_22252\2002147470.py:2: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.histplot(data=df, x='Stage', kde=True, palette='hot')
# <Axes: xlabel='Stage', ylabel='Count'>

# %%
cat_data = pd.DataFrame(df[['Smoking_History', 'Treatment', 'Ethnicity','Insurance_Type']])
cat_data
# Out:
#       Smoking_History          Treatment         Ethnicity Insurance_Type
# 0      Current Smoker            Surgery          Hispanic       Medicare
# 1        Never Smoked  Radiation Therapy         Caucasian        Private
# 2       Former Smoker       Chemotherapy  African American          Other
# 3      Current Smoker       Chemotherapy  African American       Medicare
# 4        Never Smoked  Radiation Therapy             Asian       Medicaid
# ...               ...                ...               ...            ...
# 23653   Former Smoker       Chemotherapy         Caucasian        Private
# 23654  Current Smoker  Radiation Therapy             Asian          Other
# 23655   Former Smoker       Chemotherapy             Asian        Private
# 23656   Former Smoker  Radiation Therapy  African American       Medicare
# 23657   Former Smoker       Chemotherapy             Other       Medicare
#
# [23658 rows x 4 columns]

# %%
data = pd.get_dummies(df, columns = ['Smoking_History','Treatment','Ethnicity','Insurance_Type'])
data = pd.DataFrame(data)
data
# Out:
#        Age  Gender  Tumor_Size_mm Tumor_Location      Stage  Survival_Months  \
# 0       68    Male      81.678677     Lower Lobe  Stage III               44
# 1       58    Male      78.448272     Lower Lobe    Stage I              101
# 2       44    Male      67.714305     Lower Lobe    Stage I               69
# 3       72    Male      70.806008     Lower Lobe  Stage III               95
# 4       37  Female      87.272433     Lower Lobe   Stage IV              105
# ...    ...     ...            ...            ...        ...              ...
# 23653   45    Male      91.279410    Middle Lobe    Stage I               16
# 23654   31    Male      45.139048     Upper Lobe   Stage IV               81
# 23655   74    Male      89.640323     Upper Lobe   Stage IV               52
# 23656   47  Female      45.770358    Middle Lobe    Stage I               26
# 23657   64    Male      13.460912     Upper Lobe    Stage I                1
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23658 entries, 0 to 23657
# Data columns (total 49 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Age                               23658 non-null  int64
#  1   Gender                            23658 non-null  object
#  2   Tumor_Size_mm                     23658 non-null  float64
#  3   Tumor_Location                    23658 non-null  object
#  4   Stage                             23658 non-null  object
#  5   Survival_Months                   23658 non-null  int64
#  6   Family_History                    23658 non-null  object
#  7   Comorbidity_Diabetes              23658 non-null  object
#  8   Comorbidity_Hypertension          23658 non-null  object
#  9   Comorbidity_Heart_Disease         23658 non-null  object
#  10  Comorbidity_Chronic_Lung_Disease  23658 non-null  object
# ...

# %%
data.isna().sum()
# Out:
# Age                                 0
# Gender                              0
# Tumor_Size_mm                       0
# Tumor_Location                      0
# Stage                               0
# Survival_Months                     0
# Family_History                      0
# Comorbidity_Diabetes                0
# Comorbidity_Hypertension            0
# Comorbidity_Heart_Disease           0
# Comorbidity_Chronic_Lung_Disease    0
# Comorbidity_Kidney_Disease          0
# Comorbidity_Autoimmune_Disease      0
# Comorbidity_Other                   0
# Performance_Status                  0
# Blood_Pressure_Systolic             0
# Blood_Pressure_Diastolic            0
# Blood_Pressure_Pulse                0
# Hemoglobin_Level                    0
# White_Blood_Cell_Count              0
# Platelet_Count                      0
# Albumin_Level                       0
# Alkaline_Phosphatase_Level          0
# Alanine_Aminotransferase_Level      0
# Aspartate_Aminotransferase_Level    0
# ...

# %%
data
# Out:
#        Age  Gender  Tumor_Size_mm Tumor_Location      Stage  Survival_Months  \
# 0       68    Male      81.678677     Lower Lobe  Stage III               44
# 1       58    Male      78.448272     Lower Lobe    Stage I              101
# 2       44    Male      67.714305     Lower Lobe    Stage I               69
# 3       72    Male      70.806008     Lower Lobe  Stage III               95
# 4       37  Female      87.272433     Lower Lobe   Stage IV              105
# ...    ...     ...            ...            ...        ...              ...
# 23653   45    Male      91.279410    Middle Lobe    Stage I               16
# 23654   31    Male      45.139048     Upper Lobe   Stage IV               81
# 23655   74    Male      89.640323     Upper Lobe   Stage IV               52
# 23656   47  Female      45.770358    Middle Lobe    Stage I               26
# 23657   64    Male      13.460912     Upper Lobe    Stage I                1
#
# ...

# %%
objects = data.select_dtypes(include=["object"])
objects_col = list(objects.columns)
objects_col
# Out:
# ['Gender',
#  'Tumor_Location',
#  'Stage',
#  'Family_History',
#  'Comorbidity_Diabetes',
#  'Comorbidity_Hypertension',
#  'Comorbidity_Heart_Disease',
#  'Comorbidity_Chronic_Lung_Disease',
#  'Comorbidity_Kidney_Disease',
#  'Comorbidity_Autoimmune_Disease',
#  'Comorbidity_Other']

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23658 entries, 0 to 23657
# Data columns (total 49 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Age                               23658 non-null  int64
#  1   Gender                            23658 non-null  object
#  2   Tumor_Size_mm                     23658 non-null  float64
#  3   Tumor_Location                    23658 non-null  object
#  4   Stage                             23658 non-null  object
#  5   Survival_Months                   23658 non-null  int64
#  6   Family_History                    23658 non-null  object
#  7   Comorbidity_Diabetes              23658 non-null  object
#  8   Comorbidity_Hypertension          23658 non-null  object
#  9   Comorbidity_Heart_Disease         23658 non-null  object
#  10  Comorbidity_Chronic_Lung_Disease  23658 non-null  object
# ...

# %% [markdown]
# convert the boolean into 1 or 0

# %%
from sklearn.preprocessing import LabelEncoder

LE = LabelEncoder()
for i in objects_col:
    data[i] = LE.fit_transform(data[i])
    if i == 'Stage':
        continue
data
# Out:
#        Age  Gender  Tumor_Size_mm  Tumor_Location  Stage  Survival_Months  \
# 0       68       1      81.678677               0      2               44
# 1       58       1      78.448272               0      0              101
# 2       44       1      67.714305               0      0               69
# 3       72       1      70.806008               0      2               95
# 4       37       0      87.272433               0      3              105
# ...    ...     ...            ...             ...    ...              ...
# 23653   45       1      91.279410               1      0               16
# 23654   31       1      45.139048               2      3               81
# 23655   74       1      89.640323               2      3               52
# 23656   47       0      45.770358               1      0               26
# 23657   64       1      13.460912               2      0                1
#
#        Family_History  Comorbidity_Diabetes  Comorbidity_Hypertension  \
# ...

# %% [markdown]
# adjustment Stage values

# %%
#Define
Stage_values = {'Stage': {2: 3, 0: 1, 3:4, 1:2}}

#replace
data.replace(Stage_values, inplace=True)
data
# Out:
#        Age  Gender  Tumor_Size_mm  Tumor_Location  Stage  Survival_Months  \
# 0       68       1      81.678677               0      3               44
# 1       58       1      78.448272               0      1              101
# 2       44       1      67.714305               0      1               69
# 3       72       1      70.806008               0      3               95
# 4       37       0      87.272433               0      4              105
# ...    ...     ...            ...             ...    ...              ...
# 23653   45       1      91.279410               1      1               16
# 23654   31       1      45.139048               2      4               81
# 23655   74       1      89.640323               2      4               52
# 23656   47       0      45.770358               1      1               26
# 23657   64       1      13.460912               2      1                1
#
#        Family_History  Comorbidity_Diabetes  Comorbidity_Hypertension  \
# ...

# %% [markdown]
# Visualize

# %%
import matplotlib.pyplot as plt
import seaborn as sns

exclude_columns = ['Column_Name_1', 'Column_Name_2']  # Declare blank column

columns_to_plot = [col for col in data.columns if col not in exclude_columns]

num_plots = len(columns_to_plot)
ncols = 3
nrows = (num_plots + ncols - 1) // ncols 

fig, axes = plt.subplots(nrows=nrows, ncols=ncols, figsize=(9, 30))
axes = axes.flat

color_cycle = list(plt.rcParams['axes.prop_cycle'])
num_colors = len(color_cycle)

for i, num_col in enumerate(columns_to_plot):
    sns.histplot(data,
                 x=num_col,
                 stat='count',
                 kde=True,
                 color=color_cycle[i % num_colors]["color"],
                 line_kws={'linewidth': 2, 'linestyle': 'dashed'},
                 alpha=0.4,
                 ax=axes[i])
    sns.rugplot(data,
                x=num_col,
                color=color_cycle[i % num_colors]["color"],
                ax=axes[i], alpha=0.7)
    axes[i].set_xlabel(" ")
    axes[i].set_ylabel("Count", fontsize=7, fontweight='bold', color='black')
    axes[i].set_title(num_col, fontsize=8, fontweight='bold', color='black')
    axes[i].tick_params(labelsize=6)

# Hide empty subplots
for j in range(i + 1, len(axes)):
    fig.delaxes(axes[j])

fig.suptitle('Distribution of Data', fontsize=12, fontweight='bold', color='darkred', y=0.92)
fig.tight_layout()
fig.subplots_adjust(top=0.9)
plt.show()

# %%
plt.figure(figsize=(10, 5))
sns.histplot(data=data, x='Stage', kde=True, palette='hot')
# Out:
# C:\Users\lukad\AppData\Local\Temp\ipykernel_22252\2186162384.py:2: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.histplot(data=data, x='Stage', kde=True, palette='hot')
# <Axes: xlabel='Stage', ylabel='Count'>

# %%
data
# Out:
#        Age  Gender  Tumor_Size_mm  Tumor_Location  Stage  Survival_Months  \
# 0       68       1      81.678677               0      3               44
# 1       58       1      78.448272               0      1              101
# 2       44       1      67.714305               0      1               69
# 3       72       1      70.806008               0      3               95
# 4       37       0      87.272433               0      4              105
# ...    ...     ...            ...             ...    ...              ...
# 23653   45       1      91.279410               1      1               16
# 23654   31       1      45.139048               2      4               81
# 23655   74       1      89.640323               2      4               52
# 23656   47       0      45.770358               1      1               26
# 23657   64       1      13.460912               2      1                1
#
#        Family_History  Comorbidity_Diabetes  Comorbidity_Hypertension  \
# ...

# %%
data.describe()
# Out:
#                 Age        Gender  Tumor_Size_mm  Tumor_Location  \
# count  23658.000000  23658.000000   23658.000000    23658.000000
# mean      54.439344      0.504016      55.383736        1.004565
# std       14.396386      0.499994      26.004354        0.815880
# min       30.000000      0.000000      10.004279        0.000000
# 25%       42.000000      0.000000      32.972797        0.000000
# 50%       54.000000      1.000000      55.296297        1.000000
# 75%       67.000000      1.000000      78.190014        2.000000
# max       79.000000      1.000000      99.990554        2.000000
#
#               Stage  Survival_Months  Family_History  Comorbidity_Diabetes  \
# count  23658.000000     23658.000000    23658.000000          23658.000000
# mean       2.508876        59.863809        0.491335              0.502874
# std        1.121307        34.246042        0.499935              0.500002
# min        1.000000         1.000000        0.000000              0.000000
# ...

# %%
import numpy as np

plt.figure(figsize=(40, 20))
matrix = np.triu(data.describe())
sns.heatmap(data.describe(), annot=True, linewidth=.10, cmap="Paired", mask=matrix, linecolor='black', linestyle='-', edgecolor='black')
# Out:
# <Axes: >

# %%
data.corr()
# Out:
#                                        Age    Gender  Tumor_Size_mm  \
# Age                               1.000000  0.001340      -0.007533
# Gender                            0.001340  1.000000      -0.009093
# Tumor_Size_mm                    -0.007533 -0.009093       1.000000
# Tumor_Location                   -0.005177 -0.006988      -0.003113
# Stage                             0.006894  0.003028      -0.001959
# Survival_Months                   0.002345  0.000071       0.012208
# Family_History                   -0.012956 -0.001129      -0.010273
# Comorbidity_Diabetes             -0.001849  0.005872       0.002746
# Comorbidity_Hypertension          0.001160 -0.009532       0.003092
# Comorbidity_Heart_Disease         0.005016  0.000787       0.005215
# Comorbidity_Chronic_Lung_Disease -0.002316  0.007557       0.004063
# Comorbidity_Kidney_Disease        0.007109  0.000445      -0.000761
# Comorbidity_Autoimmune_Disease   -0.005403  0.011487       0.005848
# ...

# %%
plt.figure(figsize=(40, 20))
sns.heatmap(data.corr())
top_corr_features = data.corr().index
g = sns.heatmap(data[top_corr_features].corr(), annot=True, linewidth=.10, cmap="rocket")

# %%
plt.figure(figsize=(40, 20))
sns.histplot(data=data.corr(), kde=True, palette='hot')
# Out:
# <Axes: ylabel='Count'>
# C:\Users\lukad\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\IPython\core\events.py:82: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   func(*args, **kwargs)
# C:\Users\lukad\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\IPython\core\pylabtools.py:170: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# Standard scaling

# %%
decimal_values = data.select_dtypes(include=["float64"])
decimal_values_columns = list(decimal_values.columns)
print(decimal_values_columns)
# Out:
# ['Tumor_Size_mm', 'Hemoglobin_Level', 'White_Blood_Cell_Count', 'Platelet_Count', 'Albumin_Level', 'Alkaline_Phosphatase_Level', 'Alanine_Aminotransferase_Level', 'Aspartate_Aminotransferase_Level', 'Creatinine_Level', 'LDH_Level', 'Calcium_Level', 'Phosphorus_Level', 'Glucose_Level', 'Potassium_Level', 'Sodium_Level', 'Smoking_Pack_Years']

# %%
len(decimal_values_columns)
# Out:
# 16

# %%
decimal_values.describe()
# Out:
#        Tumor_Size_mm  Hemoglobin_Level  White_Blood_Cell_Count  \
# count   23658.000000      23658.000000            23658.000000
# mean       55.383736         14.000137                6.735637
# std        26.004354          2.301411                1.879292
# min        10.004279         10.000070                3.501213
# 25%        32.972797         11.990625                5.108723
# 50%        55.296297         13.983383                6.729774
# 75%        78.190014         15.999260                8.353701
# max        99.990554         17.999957                9.999535
#
#        Platelet_Count  Albumin_Level  Alkaline_Phosphatase_Level  \
# count    23658.000000   23658.000000                23658.000000
# mean       299.867482       3.998981                   75.027604
# std         86.897568       0.576931                   25.936175
# min        150.017892       3.000080                   30.007235
# 25%        224.884576       3.504579                   52.624860
# ...

# %%
col = list(data.columns)
print(col)
# Out:
# ['Age', 'Gender', 'Tumor_Size_mm', 'Tumor_Location', 'Stage', 'Survival_Months', 'Family_History', 'Comorbidity_Diabetes', 'Comorbidity_Hypertension', 'Comorbidity_Heart_Disease', 'Comorbidity_Chronic_Lung_Disease', 'Comorbidity_Kidney_Disease', 'Comorbidity_Autoimmune_Disease', 'Comorbidity_Other', 'Performance_Status', 'Blood_Pressure_Systolic', 'Blood_Pressure_Diastolic', 'Blood_Pressure_Pulse', 'Hemoglobin_Level', 'White_Blood_Cell_Count', 'Platelet_Count', 'Albumin_Level', 'Alkaline_Phosphatase_Level', 'Alanine_Aminotransferase_Level', 'Aspartate_Aminotransferase_Level', 'Creatinine_Level', 'LDH_Level', 'Calcium_Level', 'Phosphorus_Level', 'Glucose_Level', 'Potassium_Level', 'Sodium_Level', 'Smoking_Pack_Years', 'Smoking_History_Current Smoker', 'Smoking_History_Former Smoker', 'Smoking_History_Never Smoked', 'Treatment_Chemotherapy', 'Treatment_Radiation Therapy', 'Treatment_Surgery', 'Treatment_Targeted Therapy', 'Ethnicity_African American', 'Ethnicity_Asian', 'Ethnicity_Cauc
# ...

# %% [markdown]
# drop the data that need to make scaling

# %%
data_scaling = pd.DataFrame(data[['Tumor_Size_mm','Survival_Months','Platelet_Count','Blood_Pressure_Systolic','Blood_Pressure_Pulse','Alkaline_Phosphatase_Level','LDH_Level','Glucose_Level','Sodium_Level','Smoking_Pack_Years']])
data_scaling
# Out:
#        Tumor_Size_mm  Survival_Months  Platelet_Count  \
# 0          81.678677               44      321.735266
# 1          78.448272              101      251.581538
# 2          67.714305               69      393.456532
# 3          70.806008               95      275.177898
# 4          87.272433              105      381.705572
# ...              ...              ...             ...
# 23653      91.279410               16      357.180896
# 23654      45.139048               81      448.588479
# 23655      89.640323               52      341.790190
# 23656      45.770358               26      163.957566
# 23657      13.460912                1      390.222116
#
#        Blood_Pressure_Systolic  Blood_Pressure_Pulse  \
# 0                          161                    92
# 1                          101                    93
# 2                          109                    81
# 3                          103                    68
# ...

# %%
data_scaling.describe()
# Out:
#        Tumor_Size_mm  Survival_Months  Platelet_Count  \
# count   23658.000000     23658.000000    23658.000000
# mean       55.383736        59.863809      299.867482
# std        26.004354        34.246042       86.897568
# min        10.004279         1.000000      150.017892
# 25%        32.972797        30.000000      224.884576
# 50%        55.296297        60.000000      299.933443
# 75%        78.190014        89.000000      375.437029
# max        99.990554       119.000000      449.974734
#
#        Blood_Pressure_Systolic  Blood_Pressure_Pulse  \
# count             23658.000000          23658.000000
# mean                134.462381             79.585299
# std                  26.020492             11.546690
# min                  90.000000             60.000000
# 25%                 112.000000             70.000000
# 50%                 134.000000             80.000000
# 75%                 157.000000             90.000000
# ...

# %%
data.drop(['Tumor_Size_mm','Survival_Months','Platelet_Count','Blood_Pressure_Systolic','Blood_Pressure_Pulse','Alkaline_Phosphatase_Level','LDH_Level','Glucose_Level','Sodium_Level','Smoking_Pack_Years'], axis=1, inplace=True)
data
# Out:
#        Age  Gender  Tumor_Location  Stage  Family_History  \
# 0       68       1               0      3               0
# 1       58       1               0      1               1
# 2       44       1               0      1               1
# 3       72       1               0      3               1
# 4       37       0               0      4               0
# ...    ...     ...             ...    ...             ...
# 23653   45       1               1      1               0
# 23654   31       1               2      4               0
# 23655   74       1               2      4               1
# 23656   47       0               1      1               0
# 23657   64       1               2      1               0
#
#        Comorbidity_Diabetes  Comorbidity_Hypertension  \
# 0                         1                         1
# 1                         1                         1
# 2                         0                         0
# ...
